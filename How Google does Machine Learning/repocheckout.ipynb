# %%
# %bash
git clone https://github.com/GoogleCloudPlatform/training-data-analyst
rm -rf training-data-analyst/.git
# Out:
# Cloning into 'training-data-analyst'...

# %%
# !ls
# Out:
# docs  notebooks  repocheckout.ipynb  training-data-analyst
